# %%
# !git clone https://github.com/tinyabdu/sapa.git
# Out:
# Cloning into 'sapa'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 0), reused 20 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 13.15 KiB | 1.88 MiB/s, done.

# %%
# %cd /content/sapa
# Out:
# /content/sapa

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 2.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 120.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 75.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 127.7 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 85.4 MB/s eta 0:00:00
# ...

# %%
# !ls /content
# Out:
# sample_data  sapa

# %%
The main script is already run in cell 4 from `/content/sapa/deploy` with:

```bash
# %cd /content/sapa/deploy
# !python main.py
```

To test text, run that cell and then provide the sample text input as expected by `main.py` (e.g. via CLI or the app’s input prompt).

# %%
# !ls
# Out:
# notebook.ipynb	README.md  requirements.txt  Sapa

# %%
# %cd /content/sapa
# Out:
# /content/sapa

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 1.14 KiB | 584.00 KiB/s, done.
# From https://github.com/tinyabdu/sapa
#  * branch            main       -> FETCH_HEAD
#    efd1d7c..1d9c896  main       -> origin/main
# Updating efd1d7c..1d9c896
# Fast-forward
#  Sapa/deploy/main.py | 35 +++++++++++++++++------
#  notebook.ipynb      | 82 ++++++++++++++++++++++++++++++++++++++++++++++-------
#  2 files changed, 99 insertions(+), 18 deletions(-)

# %%
# %cd /content/sapa/Sapa
# !PYTHONPATH=/content/sapa/Sapa python deploy/main.py
# Out:
# /content/sapa/Sapa
# Traceback (most recent call last):
#   File "/content/sapa/Sapa/deploy/main.py", line 45, in <module>
#     app = FastAPI(title="From-Scratch AI Platform", version="1.0", lifespan=lifespan)
#                                                                             ^^^^^^^^
# NameError: name 'lifespan' is not defined

# %%
# Running the Project

To run the project, execute the following command:

```bash
# %cd /content/sapa/Sapa
# !PYTHONPATH=/content/sapa/Sapa python deploy/main.py
```

This sets the Python path to include the Sapa module directory and runs the main.py script from the deploy folder. The application will start and prompt you for text input to process.
